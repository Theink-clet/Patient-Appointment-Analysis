# %% [markdown]
# # Questioning Data
#
# ## 1.`Data Gathering`
#
# ###    a.  Aplication Program Interface (API)
#
# ###    b.  Database
#
# ###    c.  Downloaded files
#
# ## 2.`Data Assessment`
#
# ### a. Types
#
# ####      i. Visual Assessment
# ####      ii. Programatic Assessment
#
# ### b. Data Errors
#
# ####  i. Cleanliness issues
#
# #####       Missinf values
# #####       Duplicate values
# #####       Incorrect data types
# #####       Wrong Spellings, etc
#
# #### ii. Tidiness issues a. Every observation should form a row b. Every feature forms a column c. Every observational unit forms a table
#
# ## 3. `Data Wrangling`
#
# ###     a. Define: Define the issue
# ###     b. Code: Code the solution  to the issue defined above
# ###     c. Test: Test to ensure that our code executes successfully
#
# ##  4. `Exploratory Data Analysis`
#
# ###       a. Feature engineering
#
# ##  5.  `Communication insights`
#
# ###           a. Visualization (Charts, tables, maps, etc)
# ###           b. Presentation

# %% [markdown]
# # Questions
#
# `1. Which `gender` is more likely to miss an appointment?`
# `2. What age range are more likely to miss an appointment?`
# `3. Are patients from a particular neighborhood more likely to miss an appointment?`
# `4. Are patients who got an SMS notification more likely to miss an appointment?`
# `Are patients more likely to miss an appointment on a certain day?`

# %% [markdown]
# # Questions
#
# 1. Whichgenderis more likely to miss an appointment?
# 2. What age range are more likely to miss an appointment?
# 3. Are patients from a particular neighborhood more likely to miss an appointment?
# 4. Are patients who got an SMS notification more likely to miss an appointment?
# 5. Are patients more likely to miss an appointment on a certain day?

# %%
file = './Datasets/noshowappointments-kagglev2-may-2016.csv' #input the data folder name and copy the data name. this data is a downloaded file from India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(file)

# %%
df.head ()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.tail ()
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 110522  2016-06-07T00:00:00Z   56   MARIA ORTIZ            0             0
# 110523  2016-06-07T00:00:00Z   51   MARIA ORTIZ            0             0
# 110524  2016-06-07T00:00:00Z   21   MARIA ORTIZ            0             0
# 110525  2016-06-07T00:00:00Z   38   MARIA ORTIZ            0             0
# 110526  2016-06-07T00:00:00Z   54   MARIA ORTIZ            0             0
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# 110522         0           0        0             1      No
# ...

# %%
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df.sample ()
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 55717  1.896143e+10        5617841      F  2016-04-25T17:18:27Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 55717  2016-05-30T00:00:00Z   53      REDENÇÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 55717         0           0        1             1     Yes

# %%
df.sample(5)
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 75003   1.823354e+13        5618733      F  2016-04-26T07:24:04Z
# 9088    2.488590e+12        5728958      M  2016-05-24T07:03:20Z
# 19018   1.393763e+13        5643762      F  2016-05-02T07:51:31Z
# 35243   3.325464e+12        5747573      F  2016-05-30T15:52:25Z
# 102299  9.486575e+12        5762595      F  2016-06-02T07:56:24Z
#
#               AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 75003   2016-05-02T00:00:00Z    7         COMDUSA            0             0
# 9088    2016-05-24T00:00:00Z   79   SANTO ANTÔNIO            0             1
# 19018   2016-05-03T00:00:00Z   43  FORTE SÃO JOÃO            0             0
# 35243   2016-05-30T00:00:00Z   33   SÃO CRISTÓVÃO            0             0
# 102299  2016-06-02T00:00:00Z    5        REDENÇÃO            0             0
#
#         Diabetes  Alcoholism  Handcap  SMS_received No-show
# ...

# %%
df['Gender']
# Out:
# 0         F
# 1         M
# 2         F
# 3         F
# 4         F
#          ..
# 110522    F
# 110523    F
# 110524    F
# 110525    F
# 110526    F
# Name: Gender, Length: 110527, dtype: object

# %%
df.Gender
# Out:
# 0         F
# 1         M
# 2         F
# 3         F
# 4         F
#          ..
# 110522    F
# 110523    F
# 110524    F
# 110525    F
# 110526    F
# Name: Gender, Length: 110527, dtype: object

# %%
df[['Gender','Age']]
# Out:
#        Gender  Age
# 0           F   62
# 1           M   56
# 2           F   62
# 3           F    8
# 4           F   56
# ...       ...  ...
# 110522      F   56
# 110523      F   51
# 110524      F   21
# 110525      F   38
# 110526      F   54
#
# [110527 rows x 2 columns]

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.describe ()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df.isna().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.query('Age == -1')
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %% [markdown]
# # Assessment

# %% [markdown]
# ## Cleanliness
# 1. `Age`: Age cannot be -1
# 2.`ScheduledDay` and `AppointmentDay` are objects, should be datetime
#
# ## Tidiness

# %%
df[['Gender','Age','PatientId']]
# Out:
#        Gender  Age     PatientId
# 0           F   62  2.987250e+13
# 1           M   56  5.589978e+14
# 2           F   62  4.262962e+12
# 3           F    8  8.679512e+11
# 4           F   56  8.841186e+12
# ...       ...  ...           ...
# 110522      F   56  2.572134e+12
# 110523      F   51  3.596266e+12
# 110524      F   21  1.557663e+13
# 110525      F   38  9.213493e+13
# 110526      F   54  3.775115e+14
#
# [110527 rows x 3 columns]

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ### Define: It is the process of removing errors and combining complex data sets to make them more accessible and easier to analyze
#
# `Age`:

# %%
df['Age']= df.Age.abs()

# %% [markdown]
# ## Test

# %%
df.Age.min()
# Out:
# 0

# %% [markdown]
# ## Define:
# `ScheduleDay and AppointmentDay` to be converted to datetime

# %% [markdown]
# ## Code

# %%
df['Age'].astype(int)
# Out:
# 0         62
# 1         56
# 2         62
# 3          8
# 4         56
#           ..
# 110522    56
# 110523    51
# 110524    21
# 110525    38
# 110526    54
# Name: Age, Length: 110527, dtype: int32

# %%
pd.to_datetime(df.ScheduledDay)
# Out:
# 0        2016-04-29 18:38:08+00:00
# 1        2016-04-29 16:08:27+00:00
# 2        2016-04-29 16:19:04+00:00
# 3        2016-04-29 17:29:31+00:00
# 4        2016-04-29 16:07:23+00:00
#                     ...
# 110522   2016-05-03 09:15:35+00:00
# 110523   2016-05-03 07:27:33+00:00
# 110524   2016-04-27 16:03:52+00:00
# 110525   2016-04-27 15:09:23+00:00
# 110526   2016-04-27 13:30:56+00:00
# Name: ScheduledDay, Length: 110527, dtype: datetime64[ns, UTC]

# %%
df['ScheduledDay'] =pd.to_datetime(df.ScheduledDay)
df['AppointmentDay'] =pd.to_datetime(df.AppointmentDay)

# %% [markdown]
# ### Test

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  datetime64[ns, UTC]
#  4   AppointmentDay  110527 non-null  datetime64[ns, UTC]
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: datetime64[ns, UTC](2), float64(1), int64(8), object(3)
# memory usage: 11.8+ MB

# %%
df.iloc [20:26]
# Out:
#        PatientId  AppointmentID Gender              ScheduledDay  \
# 20  6.222575e+14        5626083      F 2016-04-27 07:51:14+00:00
# 21  1.215484e+13        5628338      F 2016-04-27 10:50:45+00:00
# 22  8.632298e+14        5616091      M 2016-04-25 13:29:16+00:00
# 23  2.137540e+14        5634142      F 2016-04-28 10:27:05+00:00
# 24  8.734858e+12        5641780      F 2016-04-29 14:19:19+00:00
# 25  5.819370e+12        5624020      M 2016-04-26 15:04:17+00:00
#
#               AppointmentDay  Age   Neighbourhood  Scholarship  Hipertension  \
# 20 2016-04-29 00:00:00+00:00   30  NOVA PALESTINA            0             0
# 21 2016-04-29 00:00:00+00:00    4       CONQUISTA            0             0
# 22 2016-04-29 00:00:00+00:00   13       CONQUISTA            0             0
# 23 2016-04-29 00:00:00+00:00   46       CONQUISTA            0             0
# 24 2016-04-29 00:00:00+00:00   65      TABUAZEIRO            0             0
# ...

# %%
df.loc[df.Gender.isna()]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show]
# Index: []

# %%
df.loc[df.Age==1]
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 66      9.784893e+14        5638604      M 2016-04-29 08:12:27+00:00
# 88      4.448346e+12        5595358      M 2016-04-18 12:32:35+00:00
# 93      6.322533e+13        5639376      F 2016-04-29 09:01:10+00:00
# 95      1.986249e+14        5640307      M 2016-04-29 10:28:54+00:00
# 99      1.246213e+11        5641893      F 2016-04-29 14:38:28+00:00
# ...              ...            ...    ...                       ...
# 110338  2.292794e+12        5603688      F 2016-04-20 07:18:18+00:00
# 110344  2.351982e+13        5787397      F 2016-06-08 09:52:05+00:00
# 110462  9.848895e+14        5769406      F 2016-06-03 08:48:00+00:00
# 110467  7.682333e+13        5782376      M 2016-06-07 11:06:56+00:00
# 110472  3.124195e+13        5780919      M 2016-06-07 08:45:22+00:00
#
#                   AppointmentDay  Age   Neighbourhood  Scholarship  \
# 66     2016-04-29 00:00:00+00:00    1       CONQUISTA            0
# ...

# %%
df.loc[df.Gender=='F']
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 0       2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 2       4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3       8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4       8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
# 5       9.598513e+13        5626772      F 2016-04-27 08:36:51+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   AppointmentDay  Age      Neighbourhood  Scholarship  \
# ...

# %%
df.loc[df.Gender=='M']
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 1       5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 11      7.542951e+12        5620163      M 2016-04-26 08:44:12+00:00
# 13      9.113946e+14        5636249      M 2016-04-28 14:52:07+00:00
# 16      8.457439e+13        5633121      M 2016-04-28 08:51:47+00:00
# 22      8.632298e+14        5616091      M 2016-04-25 13:29:16+00:00
# ...              ...            ...    ...                       ...
# 110501  4.544252e+11        5758133      M 2016-06-01 10:19:12+00:00
# 110506  8.973883e+11        5758779      M 2016-06-01 11:09:20+00:00
# 110509  4.952968e+14        5786750      M 2016-06-08 08:50:51+00:00
# 110513  8.674778e+13        5785964      M 2016-06-08 07:52:55+00:00
# 110515  6.456342e+14        5778621      M 2016-06-06 15:58:05+00:00
#
#                   AppointmentDay  Age    Neighbourhood  Scholarship  \
# 1      2016-04-29 00:00:00+00:00   56  JARDIM DA PENHA            0
# ...

# %%
fdf = df.loc[df.Gender=='F']

# %%
df.shape
# Out:
# (110527, 14)

# %%
fdf.shape #f =all the female patience. df=all the data both male and female
# Out:
# (71840, 14)

# %%
df['AppDayName'] =df['AppointmentDay'].dt.day_name()

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender              ScheduledDay  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0             1         0           0        0             0      No
# ...

# %%
df.loc[df['No-show']=='Yes']
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 6       7.336882e+14        5630279      F 2016-04-27 15:05:12+00:00
# 7       3.449833e+12        5630575      F 2016-04-27 15:39:58+00:00
# 11      7.542951e+12        5620163      M 2016-04-26 08:44:12+00:00
# 17      1.479497e+13        5633460      F 2016-04-28 09:28:57+00:00
# 20      6.222575e+14        5626083      F 2016-04-27 07:51:14+00:00
# ...              ...            ...    ...                       ...
# 110484  5.133650e+14        5772155      F 2016-06-03 14:43:56+00:00
# 110492  6.456342e+14        5786741      M 2016-06-08 08:50:19+00:00
# 110496  8.544295e+13        5779046      F 2016-06-06 17:35:38+00:00
# 110515  6.456342e+14        5778621      M 2016-06-06 15:58:05+00:00
# 110516  6.923772e+13        5780205      F 2016-06-07 07:45:16+00:00
#
#                   AppointmentDay  Age   Neighbourhood  Scholarship  \
# 6      2016-04-29 00:00:00+00:00   23      GOIABEIRAS            0
# ...

# %%
df.Neighbourhood.value_counts()
# Out:
# JARDIM CAMBURI                 7717
# MARIA ORTIZ                    5805
# RESISTÊNCIA                    4431
# JARDIM DA PENHA                3877
# ITARARÉ                        3514
#                                ...
# ILHA DO BOI                      35
# ILHA DO FRADE                    10
# AEROPORTO                         8
# ILHAS OCEÂNICAS DE TRINDADE       2
# PARQUE INDUSTRIAL                 1
# Name: Neighbourhood, Length: 81, dtype: int64

# %%
df.groupby(by='Gender').mean()
# Out:
#            PatientId  AppointmentID        Age  Scholarship  Hipertension  \
# Gender
# F       1.460136e+14   5.674337e+06  38.894014     0.123232      0.213516
# M       1.502496e+14   5.677102e+06  33.736863     0.051904      0.167033
#
#         Diabetes  Alcoholism   Handcap  SMS_received
# Gender
# F       0.078035    0.017024  0.019543      0.336888
# M       0.060408    0.055238  0.027270      0.291571

# %%
df.groupby(by='Gender')['Age'].mean()
# Out:
# Gender
# F    38.894014
# M    33.736863
# Name: Age, dtype: float64

# %%
df.groupby(by='Gender')['Age'].median()
# Out:
# Gender
# F    39.0
# M    33.0
# Name: Age, dtype: float64

# %%
df.groupby(by='Gender')['Age'].median().reset_index()
# Out:
#   Gender   Age
# 0      F  39.0
# 1      M  33.0

# %%
df.groupby(by='Neighbourhood')['Age'].median().reset_index()
# Out:
#           Neighbourhood   Age
# 0             AEROPORTO  58.0
# 1            ANDORINHAS  35.0
# 2       ANTÔNIO HONÓRIO  33.0
# 3   ARIOVALDO FAVALESSA  29.0
# 4        BARRO VERMELHO  48.0
# ..                  ...   ...
# 76             SÃO JOSÉ  31.0
# 77            SÃO PEDRO  36.0
# 78           TABUAZEIRO  34.0
# 79        UNIVERSITÁRIO  40.0
# 80           VILA RUBIM  46.0
#
# [81 rows x 2 columns]

# %%
df.groupby(by=['Neighbourhood','Gender',])['Age'].median().reset_index()
# Out:
#        Neighbourhood Gender   Age
# 0          AEROPORTO      F  58.0
# 1          AEROPORTO      M  59.0
# 2         ANDORINHAS      F  37.0
# 3         ANDORINHAS      M  31.0
# 4    ANTÔNIO HONÓRIO      F  43.0
# ..               ...    ...   ...
# 154       TABUAZEIRO      M  27.0
# 155    UNIVERSITÁRIO      F  39.0
# 156    UNIVERSITÁRIO      M  50.0
# 157       VILA RUBIM      F  49.0
# 158       VILA RUBIM      M  40.5
#
# [159 rows x 3 columns]

# %%
df.groupby(by=['No-show', 'Gender']).count().reset_index()
# Out:
#   No-show Gender  PatientId  AppointmentID  ScheduledDay  AppointmentDay  \
# 0      No      F      57246          57246         57246           57246
# 1      No      M      30962          30962         30962           30962
# 2     Yes      F      14594          14594         14594           14594
# 3     Yes      M       7725           7725          7725            7725
#
#      Age  Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 0  57246          57246        57246         57246     57246       57246
# 1  30962          30962        30962         30962     30962       30962
# 2  14594          14594        14594         14594     14594       14594
# 3   7725           7725         7725          7725      7725        7725
#
#    Handcap  SMS_received  AppDayName
# 0    57246         57246       57246
# 1    30962         30962       30962
# 2    14594         14594       14594
# 3     7725          7725        7725

# %%
df['AppDayName'].value_counts() #displays the requency o each element in a column
# Out:
# Wednesday    25867
# Tuesday      25640
# Monday       22715
# Friday       19019
# Thursday     17247
# Saturday        39
# Name: AppDayName, dtype: int64

# %%
df[['AppDayName', 'No-show',]].value_counts()
# Out:
# AppDayName  No-show
# Wednesday   No         20774
# Tuesday     No         20488
# Monday      No         18025
# Friday      No         14982
# Thursday    No         13909
# Tuesday     Yes         5152
# Wednesday   Yes         5093
# Monday      Yes         4690
# Friday      Yes         4037
# Thursday    Yes         3338
# Saturday    No            30
#             Yes            9
# dtype: int64

# %%
df[df['No-show']=='Yes']
# Out:
#            PatientId  AppointmentID Gender              ScheduledDay  \
# 6       7.336882e+14        5630279      F 2016-04-27 15:05:12+00:00
# 7       3.449833e+12        5630575      F 2016-04-27 15:39:58+00:00
# 11      7.542951e+12        5620163      M 2016-04-26 08:44:12+00:00
# 17      1.479497e+13        5633460      F 2016-04-28 09:28:57+00:00
# 20      6.222575e+14        5626083      F 2016-04-27 07:51:14+00:00
# ...              ...            ...    ...                       ...
# 110484  5.133650e+14        5772155      F 2016-06-03 14:43:56+00:00
# 110492  6.456342e+14        5786741      M 2016-06-08 08:50:19+00:00
# 110496  8.544295e+13        5779046      F 2016-06-06 17:35:38+00:00
# 110515  6.456342e+14        5778621      M 2016-06-06 15:58:05+00:00
# 110516  6.923772e+13        5780205      F 2016-06-07 07:45:16+00:00
#
#                   AppointmentDay  Age   Neighbourhood  Scholarship  \
# 6      2016-04-29 00:00:00+00:00   23      GOIABEIRAS            0
# ...

# %%
age_group =[df.Age.min(), 2, 9, 19, 29, 39, 59, 80, df.Age.max()]
age_label=['infancy', 'childhood','adolescence','early adulthood','adulthood','late adulthood','early elderly','late elderly',]

# %%
df['age_group']=pd.cut(df.Age, bins=age_group, labels=age_label)

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender              ScheduledDay  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0             1         0           0        0             0      No
# ...

# %%
df.groupby(by=['No-show', 'Gender',])['PatientId'].count().reset_index()
# Out:
#   No-show Gender  PatientId
# 0      No      F      57246
# 1      No      M      30962
# 2     Yes      F      14594
# 3     Yes      M       7725

# %%
df[df['No-show']=='Yes']['Gender'].value_counts()
# Out:
# F    14594
# M     7725
# Name: Gender, dtype: int64

# %% [markdown]
# ### Question 1: Which gender is more likely to miss an appointment?
# ##### from the above result of the gender recorded a total of 7725 No-shows, compared to 14594 female that did not show up. So the female gender is more likely to miss an appointment.

# %%
df['No-show'].unique()#returns a list of unique elements in a column
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['No-show'].nunique()#returns the number of unique elements in a column
# Out:
# 2

# %%
df['AppDayName'].nunique()
# Out:
# 6

# %%
df['AppDayName'].unique()
# Out:
# array(['Friday', 'Tuesday', 'Monday', 'Wednesday', 'Thursday', 'Saturday'],
#       dtype=object)

# %%
df['AppDayName'].value_counts() #displays the frequency of each element in a column
# Out:
# Wednesday    25867
# Tuesday      25640
# Monday       22715
# Friday       19019
# Thursday     17247
# Saturday        39
# Name: AppDayName, dtype: int64

# %%
df.age_group.value_counts()
# Out:
# late adulthood     30072
# early elderly      18321
# adulthood          15171
# early adulthood    13699
# adolescence        12936
# childhood          10045
# infancy             3892
# late elderly        2852
# Name: age_group, dtype: int64

# %%
for i in df.Gender.value_counts():
    print((i/len(df))*100)
# Out:
# 64.99769287142509
# 35.00230712857492

# %%
df.Neighbourhood.value_counts()
# Out:
# JARDIM CAMBURI                 7717
# MARIA ORTIZ                    5805
# RESISTÊNCIA                    4431
# JARDIM DA PENHA                3877
# ITARARÉ                        3514
#                                ...
# ILHA DO BOI                      35
# ILHA DO FRADE                    10
# AEROPORTO                         8
# ILHAS OCEÂNICAS DE TRINDADE       2
# PARQUE INDUSTRIAL                 1
# Name: Neighbourhood, Length: 81, dtype: int64

# %%
df.corr()
# Out:
#                PatientId  AppointmentID       Age  Scholarship  Hipertension  \
# PatientId       1.000000       0.004039 -0.004138    -0.002880     -0.006441
# AppointmentID   0.004039       1.000000 -0.019125     0.022615      0.012752
# Age            -0.004138      -0.019125  1.000000    -0.092458      0.504586
# Scholarship    -0.002880       0.022615 -0.092458     1.000000     -0.019729
# Hipertension   -0.006441       0.012752  0.504586    -0.019729      1.000000
# Diabetes        0.001605       0.022628  0.292392    -0.024894      0.433086
# Alcoholism      0.011011       0.032944  0.095811     0.035022      0.087971
# Handcap        -0.007916       0.014106  0.078033    -0.008586      0.080083
# SMS_received   -0.009749      -0.256618  0.012643     0.001194     -0.006267
#
#                Diabetes  Alcoholism   Handcap  SMS_received
# PatientId      0.001605    0.011011 -0.007916     -0.009749
# AppointmentID  0.022628    0.032944  0.014106     -0.256618
# ...

# %%
df_a= pd.DataFrame(
    {
        'name': 'Dom',
        'Age': 22,
        'height': 2.0,
    },
    {
        'name': 'Tom',
        'Age': 32,
        'weight':77,
    }
)

# %%
df_b= pd.DataFrame(
    [{
        'name': 'Obi',
        'Age': 22,
        'height': 2.0,
    },
    {
        'name': 'Pal',
        'Age': 33,
        'weight': 66,
        'address':'No 4, Abc',
    }]
)

# %%
df_a
# Out:
#        name  Age  height
# name    Dom   22     2.0
# Age     Dom   22     2.0
# weight  Dom   22     2.0

# %%
df_b
# Out:
#   name  Age  height  weight    address
# 0  Obi   22     2.0     NaN        NaN
# 1  Pal   33     NaN    66.0  No 4, Abc

# %%
df_c = pd.concat([df_a, df_b], axis=1)

# %%
df_c
# Out:
#        name   Age  height name   Age  height  weight    address
# name    Dom  22.0     2.0  NaN   NaN     NaN     NaN        NaN
# Age     Dom  22.0     2.0  NaN   NaN     NaN     NaN        NaN
# weight  Dom  22.0     2.0  NaN   NaN     NaN     NaN        NaN
# 0       NaN   NaN     NaN  Obi  22.0     2.0     NaN        NaN
# 1       NaN   NaN     NaN  Pal  33.0     NaN    66.0  No 4, Abc

# %%
pd.concat([df_a, df_b], axis=0)
# Out:
#        name  Age  height  weight    address
# name    Dom   22     2.0     NaN        NaN
# Age     Dom   22     2.0     NaN        NaN
# weight  Dom   22     2.0     NaN        NaN
# 0       Obi   22     2.0     NaN        NaN
# 1       Pal   33     NaN    66.0  No 4, Abc

# %%
pd.merge(
    df_a,
    df_b,
    left_on='name',
    right_on='name'
)
# Out:
# Empty DataFrame
# Columns: [name, Age_x, height_x, Age_y, height_y, weight, address]
# Index: []

# %%
pd.merge(
    df_a,
    df_b,
    left_on='Age',
    right_on='Age'
)
# Out:
#   name_x  Age  height_x name_y  height_y  weight address
# 0    Dom   22       2.0    Obi       2.0     NaN     NaN
# 1    Dom   22       2.0    Obi       2.0     NaN     NaN
# 2    Dom   22       2.0    Obi       2.0     NaN     NaN

# %%
pd.merge(
    df_a,
    df_b,
    left_on='name',
    right_on='name',
    how='inner'
)
# Out:
# Empty DataFrame
# Columns: [name, Age_x, height_x, Age_y, height_y, weight, address]
# Index: []

# %%
pd.merge(
    df_a,
    df_b,
    right_on='Age',
    left_on='Age'
)
# Out:
#   name_x  Age  height_x name_y  height_y  weight address
# 0    Dom   22       2.0    Obi       2.0     NaN     NaN
# 1    Dom   22       2.0    Obi       2.0     NaN     NaN
# 2    Dom   22       2.0    Obi       2.0     NaN     NaN

# %%
pd.merge(
    df_a,
    df_b,
    left_on='name',
    right_on='name',
    how='outer'
)
# Out:
#   name  Age_x  height_x  Age_y  height_y  weight    address
# 0  Dom   22.0       2.0    NaN       NaN     NaN        NaN
# 1  Dom   22.0       2.0    NaN       NaN     NaN        NaN
# 2  Dom   22.0       2.0    NaN       NaN     NaN        NaN
# 3  Obi    NaN       NaN   22.0       2.0     NaN        NaN
# 4  Pal    NaN       NaN   33.0       NaN    66.0  No 4, Abc

# %%
pd.merge(
    df_a,
    df_b,
    left_on='name',
    right_on='name',
    how='left'
)
# Out:
#   name  Age_x  height_x  Age_y  height_y  weight address
# 0  Dom     22       2.0    NaN       NaN     NaN     NaN
# 1  Dom     22       2.0    NaN       NaN     NaN     NaN
# 2  Dom     22       2.0    NaN       NaN     NaN     NaN

# %%
pd.merge(
    df_a,
    df_b,
    left_on='name',
    right_on='name',
    how='outer'
)
# Out:
#   name  Age_x  height_x  Age_y  height_y  weight    address
# 0  Dom   22.0       2.0    NaN       NaN     NaN        NaN
# 1  Dom   22.0       2.0    NaN       NaN     NaN        NaN
# 2  Dom   22.0       2.0    NaN       NaN     NaN        NaN
# 3  Obi    NaN       NaN   22.0       2.0     NaN        NaN
# 4  Pal    NaN       NaN   33.0       NaN    66.0  No 4, Abc

# %%
sns.barplot(
    x = df_b.name,
    y = df_b.Age
)
# Out:
# <AxesSubplot:xlabel='name', ylabel='Age'>

# %%
sns.barplot(
    data = df_b,
    x = 'name',
    y = 'Age',
    hue='address'
)
# Out:
# <AxesSubplot:xlabel='name', ylabel='Age'>

# %%
df_b.address.fillna('XYZ, 899', inplace=True)

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender              ScheduledDay  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show  \
# 0             1         0           0        0             0      No
# ...

# %%
plt.bar(
    data =df_b,
    x ='name',
    height = 'Age'
)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.hist(
    df.Age,
    bins=25
)
# Out:
# (array([1.0243e+04, 7.2330e+03, 4.6640e+03, 6.7270e+03, 5.8100e+03,
#         6.5830e+03, 7.3160e+03, 6.0080e+03, 7.4460e+03, 5.5560e+03,
#         7.5180e+03, 7.9190e+03, 6.3310e+03, 6.7710e+03, 4.2730e+03,
#         3.5910e+03, 2.7850e+03, 1.7270e+03, 1.3100e+03, 4.7400e+02,
#         2.1300e+02, 2.2000e+01, 2.0000e+00, 0.0000e+00, 5.0000e+00]),
#  array([  0. ,   4.6,   9.2,  13.8,  18.4,  23. ,  27.6,  32.2,  36.8,
#          41.4,  46. ,  50.6,  55.2,  59.8,  64.4,  69. ,  73.6,  78.2,
#          82.8,  87.4,  92. ,  96.6, 101.2, 105.8, 110.4, 115. ]),
#  <BarContainer object of 25 artists>)

# %%
sns.kdeplot(
    data = df,
   x = 'Age',
    
)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
plt.plot(
    data =df,
    height = 'AppointmentDay'
)
# Out:
# []

# %%
df.groupby('AppointmentDay')

# %%
df.groupby('AppointmentDay')['PatientId'].count()
# Out:
# AppointmentDay
# 2016-04-29 00:00:00+00:00    3235
# 2016-05-02 00:00:00+00:00    4376
# 2016-05-03 00:00:00+00:00    4256
# 2016-05-04 00:00:00+00:00    4168
# 2016-05-05 00:00:00+00:00    4273
# 2016-05-06 00:00:00+00:00    3879
# 2016-05-09 00:00:00+00:00    4520
# 2016-05-10 00:00:00+00:00    4308
# 2016-05-11 00:00:00+00:00    4474
# 2016-05-12 00:00:00+00:00    4394
# 2016-05-13 00:00:00+00:00    3987
# 2016-05-14 00:00:00+00:00      39
# 2016-05-16 00:00:00+00:00    4613
# 2016-05-17 00:00:00+00:00    4372
# 2016-05-18 00:00:00+00:00    4373
# 2016-05-19 00:00:00+00:00    4270
# 2016-05-20 00:00:00+00:00    3828
# 2016-05-24 00:00:00+00:00    4009
# 2016-05-25 00:00:00+00:00    3909
# 2016-05-30 00:00:00+00:00    4514
# 2016-05-31 00:00:00+00:00    4279
# 2016-06-01 00:00:00+00:00    4464
# 2016-06-02 00:00:00+00:00    4310
# 2016-06-03 00:00:00+00:00    4090
# 2016-06-06 00:00:00+00:00    4692
# 2016-06-07 00:00:00+00:00    4416
# 2016-06-08 00:00:00+00:00    4479
# ...

# %%
ap =df.groupby('AppointmentDay')['PatientId'].count()

# %%
plt.plot(
    ap
)

# %%
ap.min()
# Out:
# 39

# %%
sns.lineplot(
    y=ap.values,
    x=ap.index
)
# Out:
# <AxesSubplot:xlabel='AppointmentDay'>

# %%
plt.plot(
    data =df,
    height = 'revenue'
)
# Out:
# []

# %%
plt.hist(
    df.AppointmentDay,
)
# Out:
# (array([ 7611., 16576.,  8828., 12894., 13358.,  8098.,  7918.,  4514.,
#         17143., 13587.]),
#  array([16920., 16924., 16928., 16932., 16936., 16940., 16944., 16948.,
#         16952., 16956., 16960.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(
    df.PatientId,
   
)
# Out:
# (array([85607.,  2756.,  2764.,  2629.,  2829.,  2592.,  2696.,  2828.,
#          3099.,  2727.]),
#  array([3.92178444e+04, 9.99981632e+13, 1.99996326e+14, 2.99994490e+14,
#         3.99992653e+14, 4.99990816e+14, 5.99988979e+14, 6.99987142e+14,
#         7.99985305e+14, 8.99983469e+14, 9.99981632e+14]),
#  <BarContainer object of 10 artists>)

# %%
ap =df.groupby('Age')['No-show'].count()

# %%
sns.lineplot(
    y=ap.values,
    x=ap.index
)
# Out:
# <AxesSubplot:xlabel='Age'>
